# %% [markdown]
# # ASSIGMENT 3

# %% [markdown]
# QUESTION NUMBER 1

# %%
def i():
    print("Name: Ubada Muneer")
    print("Father Name: Muneer Iqbal")
    print("Date of Birth: 07-08-2009")

i()
# Out:
# Name: Ubada Muneer
# Father Name: Muneer Ahmed
# Date of Birth: 01-01-2008

# %% [markdown]
# QUESTION NUMBER 2

# %%
name = "Ubada Muneer"
father_name = "Muneer Ahmed"
age = 18
education = "Intermediate"
city = "Karachi"

print("My Bio")
print("Name:", name)
print("Father Name:", father_name)
print("Age:", age)
print("Education:", education)
print("City:", city)

# %% [markdown]
# QUESTION NUMBER 3

# %%
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Exponent:", a ** b)

print("a == b:", a == b)
print("a != b:", a != b)
print("a > b:", a > b)
print("a < b:", a < b)
print("a >= b:", a >= b)
print("a <= b:", a <= b)

x = 5
print("x =", x)

x += 2
print("x += 2:", x)

x -= 1
print("x -= 1:", x)

x *= 3
print("x *= 3:", x)

x /= 2
print("x /= 2:", x)

x //= 2
print("x //= 2:", x)

x %= 2
print("x %= 2:", x)

x **= 3
print("x **= 3:", x)

print("and:", a > 5 and b < 5)
print("or:", a < 5 or b < 5)
print("not:", not(a < b))

print("a & b:", a & b)
print("a | b:", a | b)
print("a ^ b:", a ^ b)
print("~a:", ~a)
print("a << 1:", a << 1)
print("a >> 1:", a >> 1)

list1 = [10, 20, 30]
print("10 in list:", 10 in list1)
print("50 not in list:", 50 not in list1)

m = [1, 2]
n = m
o = [1, 2]

print("m is n:", m is n)
print("m is o:", m is o)
print("m is not o:", m is not o)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Exponent: 1000
# a == b: False
# a != b: True
# a > b: True
# a < b: False
# a >= b: True
# a <= b: False
# x = 5
# x += 2: 7
# x -= 1: 6
# x *= 3: 18
# x /= 2: 9.0
# x //= 2: 4.0
# x %= 2: 0.0
# x **= 3: 0.0
# and: True
# or: True
# not: True
# a & b: 2
# a | b: 11
# a ^ b: 9
# ~a: -11
# a << 1: 20
# a >> 1: 5
# 10 in list: True
# 50 not in list: True
# m is n: True
# m is o: False
# m is not o: True

# %% [markdown]
# QUESTION NUMBER 4

# %%
bio = int(input("enter obtained marks"))
chem = int(input("enter obtained marks"))
phy = int(input("enter obtained marks"))
math = int(input("enter obtained marks"))

total_marks = 400

obtained_marks = bio + chem + phy + math

percentage = obtained_marks/ total_marks * 100
# Out:
# enter obtained marks 100
# enter obtained marks 80
# enter obtained marks 70
# enter obtained marks 60

# %%
print(percentage)
# Out:
# 77.5
